# %% [markdown]
# <span style="color:red">Vineeth Reddy Gangula</span> ![image.png](attachment:image.png)https://courses.ineuron.ai/

# %% [markdown]
# # <span style="color:Green"># Python Basics Assignment-1</span>

# %% [markdown]
# ## 1. In the below elements which of them are values or an expression? eg:- values can be
# ## integer or string and expressions will be mathematical operators.

# %% [markdown]
# ## Ans:
# (*)  ---   expression
#
# ('hello')  ---   value
#
# (-87.8)    ---   value
#
# (-)       ---   expression
#
# (/)        ---   expression
#
# (+)        ---   expression
#
# (6)        ---   value

# %% [markdown]
# ## 2. What is the difference between string and variable?

# %% [markdown]
# # Ans
# ### String
# Strings in python are surrounded by either single quotation marks, or double quotation marks.
#
# 'hello' is the same as "hello".
#
# You can display a string literal with the print() function:
#
# #### Variable:
# It is the thing in which we can store data just like a container.
#
# Python has no command for declaring a variable.
# A variable is created the moment you first assign a value to it

# %%
## String Ex;
print('Hello World') ## single quotation marks
print("Hello World")  ## double quotation marks
print('''Hello World    
i am in Hyderabad''')   ## Triple Single Quotes
print("""Hello Am In Goa
R U Come To My Place""")  ## Triple Double Quotes
# Out:
# Hello World
# Hello World
# Hello World
# i am in Hyderabad
# Hello Am In Goa
# R U Come To My Place

# %%
## Variable Example;

a = 10   #a is a varaible name we can start with alphabets only and it will be store the value 10
b= 100    #b is a varaible name we can start with alphabets only and it will be store the value 100
c= 150    #c is a varaible name we can start with alphabets only and it will be store the value 150
print(a+b+c)  # substitute the 3 variables with their values help of print function 
## Note:
    #1) Variable can't start with any numerical number
    #2) variable can use underscores
    #3) Variables do not need to be declared with any particular type, and can even change type after they have been set.
# Out:
# 260

# %% [markdown]
# # 3. Describe three different data types.

# %% [markdown]
# ## Ans:
# ## Three Different  Data Types
# * 1)String is one datatype in python
#     - used for store Alphanumeric characters
#         * best example 'hello world', 'vineeth reddy','ineuron'.
#
# * 2)Integer
#     - used for store  Whole numbers
#         * best example 7, 12, 999
# * 3)Float (floating point)
#     - used for store number with a decimal point
#         * best example 3.15, 9.06, 00.13

# %% [markdown]
# # 4 What is an expression made up of? What do all expressions do?

# %% [markdown]
# ## Ans:
# * Expression is made up of values, containers, and mathematical operators (operands) e.g container = 100 + 300   and expressions are used to evaluate the values or represent the result on the screen.
# ##### Creating Expression is below 👇
#     - container = variable
#     - values=100,300
#     - operators=(+)

# %%
## example
container = 100+300
print(container)
# Out:
# 400

# %% [markdown]
# # 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?

# %% [markdown]
# ### Ans:
# * Expression is made up of values, containers, and mathematical operators (operands) and
# * the statement is just like a command that a python interpreter executes like  <span style="color:green">print</span>

# %% [markdown]
# # 6. After running the following code, what does the variable bacon contain?
# # bacon = 22
# # bacon + 1

# %% [markdown]
# ## Ans
# * it gives 23 as execution code

# %%
#Code 
bacon = 22
bacon+1
# Out:
# 23

# %% [markdown]
# # 7. What should the values of the following two terms be?
# # 'spam' + 'spamspam'
# # 'spam' * 3

# %% [markdown]
# ### Ans:  'spamspamspam'

# %%
#Code
'spam' + 'spamspam'
'spam' * 3
# Out:
# 'spamspamspam'

# %% [markdown]
# # 8.Why is eggs a valid variable name while 100 is invalid?

# %% [markdown]
# # Ans:
# ##### Main Reason we can't start giving variable an integer name. if we, we should begin with, a string-like alphabet name then integer.
# ##### moreover then e_100 or eggs100 or e100is valid

# %% [markdown]
# # 9. What three functions can be used to get the integer, floating-point number, or string version of a value?

# %% [markdown]
# ## Ans:
# - str(),
# - int(),
# - float()

# %% [markdown]
# # 10. Why does this expression cause an error? How can you fix it?
# ## I have eaten + 99 +  burritos.

# %% [markdown]
# ### Solution:
# * Because 99 is an integer it cannot be concatenated with strings, if we have to concatenate it we need to do typecasting.

# %%
# Fixed The Expression Like This..😎
'I have eaten ' + str(99) + ' burritos'
# Out:
# 'I have eaten 99 burritos'

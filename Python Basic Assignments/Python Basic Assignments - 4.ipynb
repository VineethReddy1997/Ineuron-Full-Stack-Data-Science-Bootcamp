# %% [markdown]
# <span style="color:yellow">Vineeth Reddy Gangula</span>![image-2.png](attachment:image-2.png)https://courses.ineuron.ai/

# %% [markdown]
# # <span style="color:yellow"># Python Basics Assignment-4</span>

# %% [markdown]
# # 1. What exactly is []?

# %% [markdown]
# #### Ans:-
#      [ ] is a empty list, like a =[ ] (Square Brackets)

# %% [markdown]
# # 2. In a list of values stored in a variable called spam, how would you assign the value 'hello' as the third value? (Assume [2, 4, 6, 8, 10] are in spam.)

# %%
# solution by changing the value in index 3
spam = [2, 4, 6, 8, 10]  # assiming spam list
spam[2] = 'hello'   # where 2 is the index value it means the hello in the third value replaced by 6
spam
# Out:
# [2, 4, 'hello', 8, 10]

# %% [markdown]
# ## Let's pretend the spam includes the list ['a', 'b', 'c', 'd'] for the next three queries.

# %% [markdown]
# ### 3. What is the value of spam[int(int('3' * 2) / 11)]?

# %%
#### Sol:-
spam = ['a', 'b','c','d']
spam[int(int('3' * 2) / 11)] # spam[int(33/11)] = spam[3]
# Out:
# 'd'

# %% [markdown]
# ### 4. What is the value of spam[-1]?

# %%
#### Sol:-
spam = ['a', 'b','c','d']
spam[-1] # negative index #
# Out:
# 'd'

# %% [markdown]
# ### 5. What is the value of spam[:2]?

# %%
#### Sol:-
spam = ['a', 'b','c','d']
spam[:2] # start 2 indexes #
# Out:
# ['a', 'b']

# %% [markdown]
# ### Let's pretend bacon has the list [3.14, 'cat' 11, 'cat' True] for the next three questions.

# %% [markdown]
# #### 6. What is the value of bacon.index('cat')?

# %%
## Sol:-
bacon = [3.14, 'cat', 11, 'cat', True]
bacon.index('cat') # it returns the index of first occurrence of 'cat'
# Out:
# 1

# %% [markdown]
# #### 7. How does bacon.append(99) change the look of the list value in bacon?

# %%
## sol:-
bacon = [3.14, 'cat', 11, 'cat', True]
bacon.append(99) # append adds the item at the end of the list
bacon
# Out:
# [3.14, 'cat', 11, 'cat', True, 99]

# %% [markdown]
# #### 8. How does bacon.remove('cat') change the look of the list in bacon?

# %%
bacon = [3.14, 'cat', 11, 'cat', True]
bacon.remove('cat') # remove first occurrence of item
bacon
# Out:
# [3.14, 11, 'cat', True]

# %% [markdown]
# # 9. What are the list concatenation and list replication operators?

# %% [markdown]
# #### Ans:-
#     ( * ) is list replication operator ( + ) is list concatination operator

# %%
a = [1,4]
# list replication
a*3
# Out:
# [1, 4, 1, 4, 1, 4]

# %%
a = [1,4]
b = [2,5]
# list concatination
a+b
# Out:
# [1, 4, 2, 5]

# %% [markdown]
# # 10. What is difference between the list methods append() and insert()?

# %% [markdown]
# #### Ans:-
#     append() Appends object to the end of the list
#     insert() Insert object before index

# %%
## Example
bacon = [3.14, 'cat', 11, 'cat', True]
bacon.append(99) # append adds the item at the end of the list
bacon
# Out:
# [3.14, 'cat', 11, 'cat', True, 99]

# %%
# solution by inserting value in 5th index
spam = [2, 4, 6, 8, 10]
spam.insert(4,'hello')
spam
# Out:
# [2, 4, 6, 8, 'hello', 10]

# %% [markdown]
# # 11. What are the two methods for removing items from a list?
# #### Ans:
#     remove and pop methods are using removing items from a list

# %%
#remove(item) - removeds first occurence of a item
bacon = [3.14, 'cat', 11, 'cat', True]
bacon.remove('cat')
bacon
# Out:
# [3.14, 11, 'cat', True]

# %%
#pop() - Remove and returns item at index (default last).
bacon = [3.14, 'cat', 11, 'cat']
bacon.pop()
bacon
# Out:
# [3.14, 'cat', 11]

# %% [markdown]
# # 12. Describe how list values and string values are identical.

# %% [markdown]
# #### Ans:-
# * The similarity between Lists and Strings in Python is that both are sequences.
# * The differences between them are that firstly, Lists are mutable but Strings are immutable.
# * Secondly, elements of a list can be of different types whereas a String only contains characters that are all of String type.
#         1.Both lists and strings can be passed to len()
#         2.Have indexes and slices
#         3.Can be used in for loops
#         4.Can be concatenated or replicated
#         5.Can be used with the in and not in operators

# %% [markdown]
# # 13. What's the difference between tuples and lists?
# #### Ans:-
#     Lists : are mutable - they can have values added, removed, or changed. lists use the square brackets, [ vineeth ]
#     Tuples : are immutable; they cannot be changed at all. Tuples are written using parentheses, ( vineeth )

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 14. How do you type a tuple value that only contains the integer 42?

# %%
tuple = (100,)
tuple
# Out:
# (100,)

# %% [markdown]
# # 15. How do you get a list value's tuple form? How do you get a tuple value's list form?

# %%
### list to tuple form
l1 = [10,20]
l = tuple(l1)
l
# Out:
# (10, 20)

# %%
### tuple to list form
t1 = (20,40)
t = list(t1)
print(t)
# Out:
# [20, 40]

# %% [markdown]
# # 16. Variables that "contain" list values are not necessarily lists themselves. Instead, what do they contain?

# %% [markdown]
# ### Ans:-
#      They contain references to list values

# %% [markdown]
# # 17. How do you distinguish between copy.copy() and copy.deepcopy()?

# %% [markdown]
# #### Ans:-
#     The copy.copy() function will do a shallow copy of a list,
#     The copy.deepcopy()function will do a deep copy of a list. only copy.deepcopy() will duplicate any lists inside the list

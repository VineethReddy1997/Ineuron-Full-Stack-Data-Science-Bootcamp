# %% [markdown]
# <span style="color:orange">Vineeth Reddy Gangula</span>![image-2.png](attachment:image-2.png)https://courses.ineuron.ai/

# %% [markdown]
# # <span style="color:orange"># Python Basics Assignment-5</span>

# %% [markdown]
# # 1. What does an empty dictionary's code look like?

# %%
### Sol:-
dict = {}
type(dict)
# Out:
# dict

# %% [markdown]
# # 2. What is the value of a dictionary value with the key 'foo' and the value 42?

# %%
####Ans:-
{'foo':42}
# Out:
# {'foo': 42}

# %% [markdown]
# # 3. What is the most significant distinction between a dictionary and a list?

# %% [markdown]
# #### Ans:-
#     Most significant difference:
#     List - items in list are Ordered
#     Dictionary : iten in dictionary are unordered

# %% [markdown]
# # 4. What happens if you try to access spam['foo'] if spam is {'bar': 100}?

# %%
spam = {'bar':100}
spam['foo']
#This will give us key error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\VINEET~1\AppData\Local\Temp/ipykernel_5344/2620492333.py in <module>
#       1 spam = {'bar':100}
# ----> 2 spam['foo']
#       3 #This will give us key error
#
# KeyError: 'foo'

# %% [markdown]
# # 5. If a dictionary is stored in spam, what is the difference between the expressions 'cat' in spam and 'cat' in spam.keys()?

# %%
##'cat' in spam
spam ={'cat':100}
'cat' in spam
# Out:
# True

# %%
## 'cat' in spam.keys()
'cat' in spam.keys()
#There is no differnce, both check if 'cat' is key of the dictionary and if its a key, returns True.
# Out:
# True

# %% [markdown]
# # 6. If a dictionary is stored in spam, what is the difference between the expressions 'cat' in spam and 'cat' in spam.values()?
# #### Ans:-
#     * 'cat' in spam checks whether there is a 'cat' key in the dictionary
#     * 'cat' in spam.values() checks whether there is a value 'cat' for one of the keys in spam.

# %%
spam ={'cat':100}
'cat' in spam.values()
# Out:
# False

# %% [markdown]
# # 7. What is a shortcut for the following code?
# #### if 'color' not in spam:
# #### spam['color'] = 'black'

# %%
spam ={'cat':100}
spam.setdefault('color','black')
spam
# Out:
# {'cat': 100, 'color': 'black'}

# %% [markdown]
# # 8. How do you "pretty print" dictionary values using which module and function?

# %%
import pprint
dict_=[ {'Name': 'vineeth', 'Age': '24', 'Country': 'India'},
  {'Name': 'krish naik', 'Age': '44', 'Country': 'italy'},
  {'Name': 'sudanshu', 'Age': '29', 'Country': 'UK'},
  {'Name': 'naveen', 'Age': '35', 'Country': 'USA'}
]

# %%
# printing with pprint()
pprint.pprint(dict_)
# Out:
# [{'Age': '24', 'Country': 'India', 'Name': 'vineeth'},
#  {'Age': '44', 'Country': 'italy', 'Name': 'krish naik'},
#  {'Age': '29', 'Country': 'UK', 'Name': 'sudanshu'},
#  {'Age': '35', 'Country': 'USA', 'Name': 'naveen'}]

# %%
#Printing with print()
print(dict_)
# Out:
# [{'Name': 'vineeth', 'Age': '24', 'Country': 'India'}, {'Name': 'krish naik', 'Age': '44', 'Country': 'italy'}, {'Name': 'sudanshu', 'Age': '29', 'Country': 'UK'}, {'Name': 'naveen', 'Age': '35', 'Country': 'USA'}]
